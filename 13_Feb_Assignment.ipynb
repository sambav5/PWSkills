# %% [markdown]
# ## Q1. Explain why we have to use the Exception class while creating a Custom Exception.
#
# Exception class is the base class for exception and all the exception must be derived from base exception class. Base exception
# class has built in exception which can be easily extended into child class

# %%
## Q2. Write a python program to print Python Exception Hierarchy


import inspect
print("The class hierarchy for built-in exceptions is:")
inspect.getclasstree(inspect.getmro(Exception))
def classtree(cls, indent=0):
    print('.' * indent, cls.__name__)
    for subcls in cls.__subclasses__():
        classtree(subcls, indent + 3)
classtree(Exception)
# Out:
# The class hierarchy for built-in exceptions is:
#  Exception
# ... TypeError
# ...... FloatOperation
# ...... MultipartConversionError
# ... StopAsyncIteration
# ... StopIteration
# ... ImportError
# ...... ModuleNotFoundError
# ...... ZipImportError
# ... OSError
# ...... ConnectionError
# ......... BrokenPipeError
# ......... ConnectionAbortedError
# ......... ConnectionRefusedError
# ......... ConnectionResetError
# ............ RemoteDisconnected
# ...... BlockingIOError
# ...... ChildProcessError
# ...... FileExistsError
# ...... FileNotFoundError
# ...... IsADirectoryError
# ...... NotADirectoryError
# ...... InterruptedError
# ......... InterruptedSystemCall
# ...... PermissionError
# ...... ProcessLookupError
# ...... TimeoutError
# ...... UnsupportedOperation
# ...... itimer_error
# ...... herror
# ...... gaierror
# ...... SSLError
# ......... SSLCertVerificationError
# ......... SSLZeroReturnError
# ......... SSLWantWriteError
# ......... SSLWantReadError
# ...

# %%
## Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

## ArithmeticError class includes errors which are specific to  numeric operations. Error includes zerodivision error, overflow error,floating point error etc.



# 1) Zerodivision Error : Ocuurs when we divide a number by 0.

i = 5

print(i/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[10], line 11
#       1 ## Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.
#       2
#       3 ## ArithmeticError class includes errors which are specific to  numeric operations. Error includes zerodivision error, overflow error,floating point error etc.
#    (...)
#       6
#       7 # 1) Zerodivision Error : Ocuurs when we divide a number by 0.
#       9 i = 5
# ---> 11 print(i/0)
#
# ZeroDivisionError: division by zero

# %%
# 2) OverflowError exception 
## An OverflowError exception is raised when an arithmetic operation exceeds the limits to be represented. 
## in Below example, overflow exception occured as result is out of range

j = 5.0

for i in range(1, 1000):
    j = j**i
    print(j)
# Out:
# 5.0
# 25.0
# 15625.0
# 5.960464477539062e+16
# 7.52316384526264e+83
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[11], line 8
#       5 j = 5.0
#       7 for i in range(1, 1000):
# ----> 8     j = j**i
#       9     print(j)
#
# OverflowError: (34, 'Numerical result out of range')

# %%
## Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

## The LookupError exception in Python forms the base class for all exceptions that are raised 
## when an index or a key is not found for a sequence or dictionary respectively.

## Example

## IndexError occurs when the index we are checking doesnot exist in the list

list1 = [1,2,3,4]

print(list1[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 10
#       1 ## Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.
#       2
#       3 ## The LookupError exception in Python forms the base class for all exceptions that are raised
#       4 ## when an index or a key is not found for a sequence or dictionary respectively.
#       5
#       6 ## Example
#       8 list1 = [1,2,3,4]
# ---> 10 print(list1[5])
#
# IndexError: list index out of range

# %%
## KeyError occurs when the key which is being searched is not exist in the dictnoary

person = {"name":"sambav","age":30,"language":"Python"}

print(person["name"])
print(person["weight"])
# Out:
# sambav
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 6
#       3 person = {"name":"sambav","age":30,"language":"Python"}
#       5 print(person["name"])
# ----> 6 print(person["weight"])
#
# KeyError: 'weight'

# %%
## Q5. Explain ImportError. What is ModuleNotFoundError?

## This error generally occurs when a class cannot be imported due to one of the following reasons:
### The imported class is in a circular dependency.
### The imported class is unavailable or was not created.
### The imported class name is misspelled.
### The imported class from a module is misplaced.
### The imported class is unavailable in the Python library

## ModulenotFound error occurs when a module doesnot exist in python library


import sambav
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 13
#       1 ## Q5. Explain ImportError. What is ModuleNotFoundError?
#       2
#       3 ## This error generally occurs when a class cannot be imported due to one of the following reasons:
#    (...)
#       9
#      10 ## ModulenotFound error occurs when a module doesnot exist in python library
# ---> 13 import sambav
#
# ModuleNotFoundError: No module named 'sambav'

# %%
## Q6. List down some best practices for exception handling in python.

## 1) Never use irrelavant and unneccesary exception handling.
## 2) use always a specific exception
## 3) Print/log always with a valid message.
## 4) Clean up all the resource at the end of the program
